# %% [markdown]
# # Data Visualization

# %% [markdown]
# Data Visualization is the graphical representation of information and data using visual elements like charts, graphs, maps, and dashboards. It helps people understand complex data sets by presenting them in a more accessible and easy-to-digest visual format.

# %% [markdown]
# ## Why Data Visualization is Important
# * **Simplifies Complex Data** - It turns large, complex datasets into visual summaries that are easier to understand.
# * **Improves Data Interpretation** - Helps identify patterns, trends, and outliers quickly that might go unnoticed in raw data.
# * **Facilitates Better Decision-Making** - Decision-makers can grasp insights quickly and act on data-driven conclusions.
# * **Enhances Communication** Makes it easier to share insights with stakeholders through visual storytelling.
# * **Saves Time** Users can comprehend large amounts of information at a glance rather than reading reports or spreadsheets.
# * **Supports Exploratory Data Analysis (EDA)** In data science and machine learning, it’s critical for understanding the structure and relationships in the data.
# * **Engages Audience** Visually appealing graphics attract more attention and help in better engagement compared to text-heavy reports.

# %% [markdown]
# ### Important Libraries in Python
# * **Pandas**: A powerful Python library used for data manipulation and analysis with DataFrame support.
# * **Matplotlib**: A foundational plotting library for creating static, customizable 2D charts in Python.
# * **Seaborn**: A Python library built on Matplotlib that provides high-level, attractive statistical visualizations.
# * **Plotly (Python)**: An interactive and animated plotting library that enables dynamic, web-based visualizations.
#
#
# docuementation of each site
# 10 different plot for each dataset
# intepret and insights from each plot
# finazlize it one notebook

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Plotting with Pandas
# [Creating Plot with Pandas](https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html) <br>
# 🔑 Key Concepts to Remember
# * **Built-in Plotting**: Pandas integrates with Matplotlib to provide easy .plot() functionality directly on Series and DataFrames.
# * **Data Types Supported**: Works well with time series, categorical, and numerical data.
# * **Kinds of Plots**: Common types include line, bar, histogram, area, scatter, box, and pie.
# * **Chaining with Data Processing**: You can chain .plot() directly after filtering or aggregating data.<br>
# * **Some common examples**
# 1. df.plot(kind='line')         # Line plot (default)
# 2. df.plot(kind='bar')          # Bar chart
# 3. df.plot(kind='barh')         # Horizontal bar chart
# 4. df.plot(kind='hist')         # Histogram

# %%
# import titatic data from seaborn library 
df=sns.load_dataset('titanic')

# %% [markdown]
# ### 1. Scatter Plot
# A scatter plot displays values for two numerical variables as points on a 2D graph, helping to visualize the relationship or correlation between them (e.g., positive, negative, or none).
# * X-axis: Independent variable
# * Y-axis: Dependent variable
# * Use Case: Ideal for spotting trends, clusters, and outliers in data.

# %%
df.plot(kind='scatter',x='age',y='fare',color='red') # we can change color using hex code or color name
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ### 2. Histogram
# set the kind argument to specify that you want a histogram:
# **kind = 'hist'** <br>
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?

# %%
df.plot(kind='hist',x='age',y='fare')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.Box Plot
# A box plot (or box-and-whisker plot) is used to display the distribution of a dataset and highlight its central tendency, spread, and outliers.
#
# * Box: Represents the interquartile range (IQR: Q1 to Q3).
# * Line inside the box: The median (Q2).
# * Whiskers: Extend to show the range (excluding outliers).
# * Dots outside whiskers: Outliers.
# <br>
# ✅ Use Case: Great for comparing distributions between groups and detecting skewness or anomalies.

# %%
# creating box plot using pandas
df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting with Matplotlib
# 🔑 [Plotting With Matplotlib](https://matplotlib.org/stable/tutorials/pyplot.html)
#
# * Core Object: pyplot module (import matplotlib.pyplot as plt) is commonly used for basic plots.
# * Figure & Axes: Everything is drawn on a Figure that contains one or more Axes (subplots).
# * Customization: Almost every element (color, label, ticks, grid, legend, etc.) can be styled.
#
# Rendering: Plots are rendered with plt.show() in most environments.

# %%
## loading dataset
data=sns.load_dataset('tips')

# %%
data.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 41       17.46  2.54  Male     No  Sun  Dinner     2

# %% [markdown]
# ### 4. Pie Charts
# A pie chart is a circular chart divided into slices to illustrate proportions or percentages of a whole. Each slice represents a category’s contribution relative to the total.
#
# * use the pie() function to draw pie charts:
# * Useful for showing part-to-whole relationships.
# * Works best with limited categories (usually under 6).
# * Slices are often labeled with percentages.

# %%
# creating pie charts using matplotlib
labels=data['sex'].unique()
plt.pie(data['sex'].value_counts())
plt.title('pie chart')
plt.legend(data['sex'].unique())

# %% [markdown]
# ### 5. Line pLot
# The line plot is a simple and effective way to display the relationship between two variables. It is a
# straight line that connects the points on the graph. The line plot is useful for showing the trend of
# a variable over time or across different categories.

# %%
# line plot
plt.plot(data['total_bill'],label='Total Bill')

# %% [markdown]
# ### 6. Bar Chart
# A bar chart represents categorical data with rectangular bars, where the length or height of each bar indicates the value or frequency of that category.
#
# * **X-axis**: Categories
# * **Y-axis**: Values (counts, measurements, etc.)<br>
# can be vertical or horizontal (bar() or barh() in Matplotlib).
# <br>
# **Use Case**: Comparing data across categories like product sales, population by country, or survey responses.

# %%
# bar chart using matplotlib on data 
plt.bar(data['sex'],data['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %% [markdown]
# ## Plotting With Seaborn
# 🔑 [Plotting with Seaborn](https://seaborn.pydata.org/tutorial/introduction.html)
# Seaborn is a visualization library built on top of matplotlib. It provides a high-level interface for
# creating attractive and informative statistical graphics.
# * **Built-in Themes**: Seaborn comes with beautiful default themes for better aesthetics (e.g., darkgrid, whitegrid, etc.).
# * **Statistical Plots**: Seaborn focuses on visualizing statistical relationships, distributions, and categorical comparisons.
# * **Automatic Estimation**: Many Seaborn plots, like regression plots, automatically fit statistical models (e.g., linear regression) to your data.

# %%
# loading dataset 
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### 7. Heatmap
# A heatmap visualizes matrix data (e.g., correlation matrices) with color gradients to represent values.

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='coolwarm')

plt.title('Heatmap of Missing Values in Titanic Dataset')
plt.show()

# %% [markdown]
# ### 8. Pair Plot
# A pair plot is a graphical representation of the relationships between multiple variables. It is a useful tool for visualizing the distribution of variables and their relationships with each other.

# %%
# Pairplot of numerical columns
sns.pairplot(df, hue="survived", dropna=True)

plt.suptitle('Pairplot of Titanic Dataset', y=1.02)
plt.show()

# %% [markdown]
# ### 9. Count Plot
# A count plot is a type of bar chart that displays the count of observations for each category. It
# is useful for visualizing categorical data and can be used to identify patterns or trends in the data.

# %%
sns.countplot(data=df,x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ### 10. Swarm Plot
# A swarm plot is a type of box plot that displays the distribution of a variable and the individual data
# points. It is useful for visualizing the distribution of a variable and identifying outliers.

# %%
sns.swarmplot(x='class',y='age',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>
# c:\Users\bashi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 11. Bar Plot
# A bar plot is a graphical representation of categorical data. It is used to compare the values of different categories. The x-axis represents the categories, and the y-axis represents the values.

# %%
# bar plot using seaborn on df

sns.barplot(x='sex',y='fare',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(x='sex',y='fare',data=df,hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# ### 11. Box Plot
# A box plot is a graphical representation of the distribution of a dataset. It is a useful tool for
# visualizing the five-number summary of a dataset: the minimum value, the first quartile (Q 1), the median (Q 2), the third quartile (Q 3), and the maximum value.

# %%
sns.boxplot(x='sex',y='age',data=df,hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ### 12. Scatter Plot
# A scatter plot is a type of plot that displays the relationship between two variables. It is a two
# dimensional plot where each point on the plot represents a data point. The x-axis represents one
# variable, and the y-axis represents another variable.

# %%
sns.scatterplot(x='age',y='fare',data=df,hue='class')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ## Plotting With Plotly
# [Plotting with Plotly](https://plotly.com/python/) <br>
# Plotly is a powerful library for creating interactive and animated plots. It provides a wide range of visualization options, including 3D plots, geographical plots, and interactive charts that allow for zooming, panning, and hovering over elements for additional information.
#
# Key Concepts to Remember
# * **Interactive Visualizations**: Plotly allows for interactive elements like zoom, pan, hover, and more.
# * **Express vs Graph Objects**:
#   * plotly.express is a simpler interface for quick plotting.
#   * plotly.graph_objects provides more fine-grained control for complex visualizations.
# * **Figure Objects**: In Plotly, everything is encapsulated in a Figure object, which can be customized and updated.
# * **Web-based**: Plots can be rendered in Jupyter Notebooks or exported to HTML, making them suitable for web apps.

# %% [markdown]
# **Additional Notes on Plotly**
# * **Hover Info**: Plotly automatically displays additional information (e.g., values) on hover.
# * **Interactivity**: You can zoom, pan, and filter data interactively.
# * **Exporting**: You can export the plots to an HTML file for sharing or embedding into websites using fig.write_html("plot.html").

# %%
import plotly.express as px

# %%
df=sns.load_dataset('penguins')

# %%
df.sample()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 247  Gentoo  Biscoe            47.8           15.0              215.0
#
#      body_mass_g   sex
# 247       5650.0  Male

# %% [markdown]
# ### 13. Bubble Chart
# A bubble chart is an extension of a scatter plot that displays three dimensions of data: the x and y positions represent two variables, while the size of each bubble represents a third variable, helping visualize relationships and compare magnitude simultaneously.

# %%
df_clean = df.dropna(subset=["bill_length_mm", "bill_depth_mm", "body_mass_g", "species"])

# Create Bubble Chart
fig = px.scatter(
    df_clean,
    x="bill_length_mm",
    y="bill_depth_mm",
    size="body_mass_g",            # Must be numeric with no NaNs
    color="species",
    title="Bubble Chart: Bill Dimensions vs Body Mass (Penguins)",
    labels={
        "bill_length_mm": "Bill Length (mm)",
        "bill_depth_mm": "Bill Depth (mm)",
        "body_mass_g": "Body Mass (g)"
    }
)
fig.show()

# %% [markdown]
# ### 14. Bar Chart
# A bar chart is a type of chart that displays data as rectangular bars. Each bar represents a value.

# %%
px.bar(df,x='species',y='body_mass_g', title='Bar Chart: Species vs Body Mass (Penguins)',color='species',labels={'species':'Species','body_mass_g':'Body Mass (g)'})

# %% [markdown]
# ### 15. 3d Line Plot
# Shows a connected path in 3D space — useful for trends or sequences.

# %%
df = sns.load_dataset("penguins").dropna()

fig = px.line_3d(
    df.sort_values(by="body_mass_g"),  # sort helps visualize direction
    x="bill_length_mm",
    y="bill_depth_mm",
    z="body_mass_g",
    color="species",
    title="3D Line Plot: Bill Dimensions and Body Mass"
)
fig.show()

# %% [markdown]
# ### 16. Animated Bar Plot: Avg Body Mass per Species Over Islands

# %%
grouped = df.groupby(['island', 'species'])['body_mass_g'].mean().reset_index()

# Animated bar chart
fig = px.bar(
    grouped,
    x="species",
    y="body_mass_g",
    color="species",
    animation_frame="island",
    title="Average Body Mass by Species Across Islands",
    labels={"body_mass_g": "Avg Body Mass (g)"}
)
fig.show()

# %% [markdown]
# ### 17. Animated Bubble Chart

# %%
df["frame"] = df.groupby("species").cumcount()

fig = px.scatter(
    df,
    x="flipper_length_mm",
    y="body_mass_g",
    size="bill_length_mm",
    color="species",
    animation_frame="frame",
    hover_name="island",
    title="Animated Bubble Plot: Flipper Length vs Body Mass",
    range_x=[170, 240],
    range_y=[2500, 6500]
)
fig.show()

# %% [markdown]
# -----
