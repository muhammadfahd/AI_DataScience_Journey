# %% [markdown]
# # Plotting with Seaborn
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.<br>
# For Detail [check out](https://seaborn.pydata.org/examples/index.html)
#
# 🌟 Unique Features of Seaborn
# * **Built-in Themes & Styles** : Beautiful default themes and color palettes make charts visually appealing out of the box.
# * **Integration with Pandas** : Directly works with DataFrames and column names, making it very intuitive.
# * **Statistical Plotting** : High-level functions like sns.boxplot(), sns.violinplot(), sns.regplot(), and sns.lmplot() automatically compute statistical estimations like confidence intervals and regression lines.
# * **Categorical Data Handling**: Seaborn shines with categorical plots like catplot(), stripplot(), swarmplot(), and more.
# * **Multi-Plot Grids**: Functions like pairplot(), facetgrid(), and jointplot() allow for complex visualizations across multiple variables with minimal code.
# * **Color Palettes** : Provides diverse color palette options (deep, muted, pastel, dark, colorblind, etc.), useful for both aesthetic and accessibility
#
# ![Seaborn Plot](./output_plots/seaborn_plots.png)

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Important Things for plotting according to grammar of graphics
# 1. Data (df)
# 2. type of plot
# 3. x-axis
# 4. y-axis
# 5. grouping (hue/color) based on categorical variable
# 6. size of plot
# 7. colro pallete
# 8. style of the plot
# 9. How do Your interpret

# %% [markdown]
# ### loading with data

# %%
## Data 
df=sns.load_dataset('titanic')

# %%
# to get over-view of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### specifiying the axix and the data

# %%
# supposing x-axis age and y-axis height
sns.scatterplot(data=df, x='age',y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ### grouping the data based on categorical data

# %%
# now grouyping the data based on some categorical data example sex
sns.scatterplot(data=df, x='age',y='fare', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ### spicify the figure size

# %%
# we can specifiy figure size
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='age',y='fare', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ### changing the color palette

# %%
# we can specifiy figure size
plt.figure(figsize=(10,6))

#changing the scatter point colors
palette={'male':'blue','female':'red'}
sns.scatterplot(data=df, x='age',y='fare', hue='sex', palette=palette)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ### labels & title

# %%
# we can specifiy figure size
plt.figure(figsize=(10,6))

#changing the scattr point colors
palette={'male':'blue','female':'red'}
sns.scatterplot(data=df, x='age',y='fare', hue='sex', palette=palette)


plt.xlabel('age')
plt.ylabel('fare')
plt.title('Scatter plot with Seaborn')
# Out:
# Text(0.5, 1.0, 'Scatter plot with Seaborn')

# %% [markdown]
# ### saving the plot

# %%
# we can specifiy figure size
plt.figure(figsize=(10,6))

#changing the scattr point colors
palette={'male':'blue','female':'red'}
sns.scatterplot(data=df, x='age',y='fare', hue='sex', palette=palette)


plt.xlabel('age')
plt.ylabel('fare')
plt.title('Scatter plot with Seaborn')

# saving a plot 
# multiple methods to save a plot  300dpi, dots per inch
plt.savefig('./output_plots/scatter_plot.png', dpi=300)  # save as PNG

# can save in svg format sa well
plt.savefig('./output_plots/scatter_plot.svg')

# %% [markdown]
# ### Changing Style & Theme

# %%
# style of plot - 
# can be like whitegrid, darkgrid, white, dark, ticks, whitegrid, darkgrid, white, dark, ticks
# can also change font  
sns.set_style('darkgrid')
sns.set_theme(style='darkgrid',font='Arial',font_scale=1.0)
sns.scatterplot(data=df, x='age',y='fare', hue='sex', palette=palette)

# %% [markdown]
# ### interpretting the results

# %% [markdown]
# interpret the result
# * x- axix =>  have age of the people in the data set on x -axis
# * y-axix => have fare of the people in the data set on y-axis
#
# * scatter plot show relationship between age & fae of titanic passengers
#
# * We further grouped the passenger by their genders such as male and female .
#
# * two male passengers gave the highest fare of 512.35 and 512.35 respectively.
#
# * oldes person at titanic is also a male passenger who is 80 years old. (As shown in the data set)

# %% [markdown]
# ## Box Plot

# %%
# we can specifiy figure size
plt.figure(figsize=(13,6))

#changing the scattr point colors
palette={'First':'blue','Second':'red','Third':'green'}
sns.boxplot(data=df, x='sex',y='fare', hue='class', palette=palette)


plt.xlabel('Sex')
plt.ylabel('fare')
plt.title('Box plot with Seaborn')

# saving a plot 
# multiple methods to save a plot  300dpi, dots per inch
plt.savefig('./output_plots/box_plot.png', dpi=300)  # save as PNG

# %% [markdown]
# ## Boxen Plot

# %%
# we can specifiy figure size
plt.figure(figsize=(10,6))

#changing the scattr point colors
palette={'First':'blue','Second':'red','Third':'green'}
sns.boxenplot(data=df, x='sex',y='fare', hue='class', palette=palette)


plt.xlabel('Sex')
plt.ylabel('fare')
plt.title('Boxen plot with Seaborn')

# saving a plot 
# multiple methods to save a plot  300dpi, dots per inch
plt.savefig('./output_plots/boxen_plot.png', dpi=300)  # save as PNG

# %% [markdown]
# ## Bar Plot

# %%
#Bar plot usinng searborn 
# we can specifiy figure size
plt.figure(figsize=(10,6))

#changing the scattr point colors
palette={'First':'blue','Second':'red','Third':'green'}
sns.barplot(data=df, x='sex',y='age', hue='class', palette=palette)


plt.xlabel('Sex')
plt.ylabel('fare')
plt.title('Bar plot with Seaborn')

# saving a plot 
# multiple methods to save a plot  300dpi, dots per inch
plt.savefig('./output_plots/bar_plot.png', dpi=300)  # save as PNG

# %% [markdown]
# ## Creating MultiPlots
# In this section, we will learn how to create multiplots. Multiplots are useful when we want to display multiple plots in a single figure.

# %% [markdown]
# ### Method 1: Using FacetGrid – Create a grid of plots by class and sex

# %%
g = sns.FacetGrid(df, col="class", row="sex")
g.map_dataframe(sns.histplot, x="age", kde=True)
plt.show()

# %% [markdown]
# ### Method 2: Using catplot – Show survival count per class

# %%
sns.catplot(data=df, x="class", hue="survived", kind="count", col="sex")
plt.show()

# %% [markdown]
# ### Method 3: Using pairplot – Relationship between multiple numeric features
# Visualize relationships and separability between classes (e.g., survived vs. not).

# %%
df_clean = df.dropna(subset=["age", "fare", "pclass", "survived"])  # Clean NaNs
sns.pairplot(df_clean, hue="survived", vars=["age", "fare", "pclass"])
plt.show()

# %% [markdown]
# ### Method 4: Using lmplot – Regression lines grouped by hue

# %%
sns.lmplot(data=df, x="age", y="fare", hue="survived", col="class", height=4)
plt.show()
