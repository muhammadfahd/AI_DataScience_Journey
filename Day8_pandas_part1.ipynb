# %% [markdown]
# # EDA (Explarotary Data Analysis ) Part1
#
# EDA | Preprocessing |
# -----|-------------|
# EDA is the process of exploring and understanding the underlying structure and patterns in the data. This step includes:  | Pre-processing involves cleaning, transforming, and preparing the data for analysis . It inludes steps 1. |
# 1.Visualizing data distributions <br> 2. Identifying relationships between variables <br>3. Detecting outliers and anomalies <br> 4. Gaining insights into the data  | 1. Handling missing values <br> 2. Data normalization <br> 3. Feature scaling <br>4. Removing outliers

# %% [markdown]
# ## Pandas Libaray:
# Pandas is a powerful and popular open-source library in Python for data manipulation and analysis. It provides data structures and functions to efficiently handle structured data, including tabular data such as spreadsheets and SQL tables.
# Pandas plays a crucial role in data science, machine learning, and AI by:
#
# 1. **Data Preparation**: Pandas helps clean, transform, and preprocess data, making it ready for machine learning algorithms.
# 2. **Data Exploration**: Pandas enables data exploration and analysis, allowing data scientists to understand the data and identify patterns.
# 3. **Data Visualization**: Pandas integrates well with visualization libraries like Matplotlib and Seaborn, enabling the creation of informative visualizations.
# ---
# **Core components**: 🧱
# Series: One-dimensional labeled arrays.
# DataFrame: Two-dimensional labeled data structures, much like a table in a database, an Excel spreadsheet, or a data frame in R.

# %% [markdown]
# ## importing libray
# pandas is the most important library

# %%
import pandas as pd

# %% [markdown]
# ## loading dataset
# this is the first important step to start EDA & working on data - load the dataset.
# * Dataset can be in any format like csv,excel,text.
# * We can also convert dataset  from one format to other like csv to exce or text

# %%
# loading data from csv file
dataset=pd.read_csv('./Datasets/population.csv')

# %% [markdown]
# ## important steps to get over-view
# Below are some basic functions which will use almost in all datasets to get overview of data
#
# Functions | Description
# ---------|----------|
#    head() | to get first few rows of dataset|
#    tail() | to get last few rows of dataset|
#    shape | to know the number rows and coloumsn|
#    info() | to get summary of data like coloumn,datatypes|
#    describe() | to get stastical summary of data like mean,min,max|

# %%
# 1- First few rows of dataset
dataset.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# last few rows
dataset.tail()
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 523   SARAROGHA TEHSIL         813.0              98180         51479
# 524    SERWEKAI TEHSIL         398.0              54540         28695
# 525      TIARZA TEHSIL         734.0              45156         23649
# 526  TOI KHULLA TEHSIL         567.0              50413         27462
# 527        WANA TEHSIL        2315.0             153156         81342
#
#      FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  \
# 523           46694                    7             110.25  ...
# ...

# %%
# to know number of rows & Coloumns
dataset.shape
# Out:
# (528, 21)

# %%
# overall summary of dataset like coloumn,datatypes 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
# gives you stastical summary like mean ,median
dataset.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %% [markdown]
# ## Checking Null Values
# function | Description |
# ---------|-------------|
# isnull() | to know if there is any null values (true/false) |
# isnull().sum() | to count the number of null values in the dataset
# isnull().sum().sum()| to count the total number of null values across all columns

# %%
# to checking null values
dataset.isnull()
# Out:
#      PROVINCE  DIVISION  DISTRICT  SUB DIVISION  AREA (sq.km)  \
# 0       False     False     False         False         False
# 1       False     False     False         False         False
# 2       False     False     False         False         False
# 3       False     False     False         False         False
# 4       False     False     False         False         False
# ..        ...       ...       ...           ...           ...
# 523     False     False     False         False         False
# 524     False     False     False         False         False
# 525     False     False     False         False         False
# 526     False     False     False         False         False
# 527     False     False     False         False         False
#
#      ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  TRANSGENDER (RURAL)  \
# 0                False         False           False                False
# ...

# %%
# to count number of null values
dataset.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# to count total number of values across all coloumns
dataset.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Missing Handling Values
# To handle missing values there are several methods
# such as
# * Imputation,
# * Deletion,
# *  placeholder values.

# %% [markdown]
# ### 1. Dropping Coloumn (Deleting)
# To drop a column in a pandas DataFrame, you can use the `drop` method. For
# example, to drop a column named 'column_name', you would use the following code:
# or we can add condition

# %%
# loading new dataset
df_new=pd.read_excel('./Datasets/titanic.xlsx')

# %%
# checking missing values
df_new.isnull().sum()
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# dropping a particular coloumn 
df_new.drop('embark_town',axis=1)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck alive  alone
# ...

# %% [markdown]
# ### Simple Imuptation
# In this section, we will explore how to handle missing data in a dataset using various imputation techniques.

# %%
df_new
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# computing mean of age to place where there is null values
df_new['age'].fillna(df_new['age'].mean(),inplace=True)
# Out:
# C:\Users\bashi\AppData\Local\Temp\ipykernel_12764\3232738057.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['age'].fillna(df_new['age'].mean(),inplace=True)

# %%
df_new
# Out:
#      Unnamed: 0  survived  pclass     sex        age  sibsp  parch     fare  \
# 0             0         0       3    male  22.000000      1      0   7.2500
# 1             1         1       1  female  38.000000      1      0  71.2833
# 2             2         1       3  female  26.000000      0      0   7.9250
# 3             3         1       1  female  35.000000      1      0  53.1000
# 4             4         0       3    male  35.000000      0      0   8.0500
# ..          ...       ...     ...     ...        ...    ...    ...      ...
# 886         886         0       2    male  27.000000      0      0  13.0000
# 887         887         1       1  female  19.000000      0      0  30.0000
# 888         888         0       3  female  29.699118      1      2  23.4500
# 889         889         1       1    male  26.000000      0      0  30.0000
# 890         890         0       3    male  32.000000      0      0   7.7500
#
# ...
